# %% [markdown]
# # 상가(상권)정보를 활용한 데이터 분석 예제
# - 데이터 용량이 크기 때문에 관련 데이터는 [다운로드](https://www.data.go.kr/data/15083033/fileData.do) 후 진행하세요.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import platform

import platform

if platform.system() == 'Windows':
    plt.rc('font',family='Malgun Gothic')
else:    
    plt.rc('font', family='AppleGothic') 
    
plt.rcParams['axes.unicode_minus'] = False

# %%
# %config InlineBackend.figure_formats = ['svg']

# %% [markdown]
# ## 데이터 불러오기

# %%
df_data_path = "../dataset/preprocessing/소상공인시장진흥공단_상가(상권)정보_부산_202112.csv"

# %%
df = pd.read_csv(df_data_path)

# %%
columns = ["상호명", "상권업종대분류명", "상권업종중분류명", "상권업종소분류명", 
           "시도명", "시군구명", "행정동명", "법정동명", "도로명", "경도", "위도"]

# %%
df = df[columns].copy()

# %% [markdown]
# ## 전처리

# %%
# 상호명이 "NaN"인 의류 관련 업체를 삭제
df.drop(df.loc[df["상호명"].isnull()].index, inplace=True)

# %%
df["상호명_소문자"] = df["상호명"].str.lower()

# %%
df.loc[df["상호명_소문자"].str.contains("이디야|이디아|ediya")]
# Out:
#               상호명 상권업종대분류명 상권업종중분류명     상권업종소분류명    시도명  시군구명  행정동명 법정동명  \
# 294         이디야커피       음식   커피점/카페  커피전문점/카페/다방  부산광역시  해운대구  반송1동  반송동
# 787         이디야커피       음식   커피점/카페  커피전문점/카페/다방  부산광역시   사하구  다대1동  다대동
# 2080        이디아커피       음식   커피점/카페  커피전문점/카페/다방  부산광역시    동구  초량3동  초량동
# 6161        이디야커피       음식   커피점/카페  커피전문점/카페/다방  부산광역시   사하구  장림2동  장림동
# 8864        이디야커피       음식   커피점/카페  커피전문점/카페/다방  부산광역시    남구  대연3동  대연동
# ...           ...      ...      ...          ...    ...   ...   ...  ...
# 128753      이디야커피       음식   커피점/카페  커피전문점/카페/다방  부산광역시   사상구  모라1동  모라동
# 129201      이디야커피       음식   커피점/카페  커피전문점/카페/다방  부산광역시   동래구   수민동  수안동
# 131192  에이디아트트립커피       음식   커피점/카페  커피전문점/카페/다방  부산광역시    동구  수정2동  수정동
# 135049        이디아       음식   커피점/카페  커피전문점/카페/다방  부산광역시   수영구   민락동  민락동
# 139265   제이디아이스포츠      스포츠   실내운동시설        스포츠센터  부산광역시    동구  범일2동  범일동
#
#                         도로명          경도         위도    상호명_소문자
# 294        부산광역시 해운대구 아랫반송로  129.148858  35.225032      이디야커피
# 787           부산광역시 사하구 다대로  128.966690  35.048200      이디야커피
# 2080     부산광역시 동구 중앙대로332번길  129.046114  35.125441      이디아커피
# 6161        부산광역시 사하구 장림번영로  128.974461  35.080463      이디야커피
# 8864    부산광역시 남구 황령대로319번가길  129.088737  35.151692      이디야커피
# ...                     ...         ...        ...        ...
# 128753   부산광역시 사상구 사상로531번길  128.986495  35.192716      이디야커피
# 129201   부산광역시 동래구 명륜로112번길  129.084789  35.203152      이디야커피
# 131192         부산광역시 동구 수정로  129.045899  35.127489  에이디아트트립커피
# 135049      부산광역시 수영구 광안해변로  129.129792  35.161088        이디아
# 139265         부산광역시 동구 범일로  129.058597  35.141323   제이디아이스포츠
#
# [119 rows x 12 columns]

# %%
df.loc[df["상호명_소문자"].str.contains("스타벅스|starbucks")]
# Out:
#               상호명 상권업종대분류명 상권업종중분류명     상권업종소분류명    시도명  시군구명  행정동명   법정동명  \
# 2765         스타벅스       음식   커피점/카페  커피전문점/카페/다방  부산광역시    동구  초량3동    초량동
# 5505         스타벅스       음식   커피점/카페  커피전문점/카페/다방  부산광역시   연제구  연산4동    연산동
# 6179         스타벅스       음식   커피점/카페  커피전문점/카페/다방  부산광역시   연제구  연산5동    연산동
# 7301         스타벅스       음식   커피점/카페  커피전문점/카페/다방  부산광역시   사하구  하단1동    하단동
# 8604    스타벅스서면NC점       음식   커피점/카페  커피전문점/카페/다방  부산광역시  부산진구  전포1동    전포동
# ...           ...      ...      ...          ...    ...   ...   ...    ...
# 127893       스타벅스       음식   커피점/카페  커피전문점/카페/다방  부산광역시   영도구   남항동  대교동1가
# 128237       스타벅스       음식       한식    한식/백반/한정식  부산광역시   강서구  명지1동    명지동
# 128880       스타벅스       음식   커피점/카페  커피전문점/카페/다방  부산광역시    남구  대연5동    대연동
# 128883       스타벅스       음식   커피점/카페  커피전문점/카페/다방  부산광역시  해운대구   좌1동     좌동
# 129268       스타벅스       음식   커피점/카페  커피전문점/카페/다방  부산광역시   금정구  구서1동    구서동
#
#                      도로명          경도         위도    상호명_소문자
# 2765       부산광역시 동구 중앙대로  129.040831  35.116346       스타벅스
# 5505       부산광역시 연제구 반송로  129.083344  35.186967       스타벅스
# 6179      부산광역시 연제구 중앙대로  129.080677  35.185431       스타벅스
# 7301      부산광역시 사하구 낙동대로  128.968878  35.105350       스타벅스
# 8604      부산광역시 부산진구 동천로  129.063037  35.157050  스타벅스서면nc점
# ...                  ...         ...        ...        ...
# 127893     부산광역시 영도구 태종로  129.037287  35.094626       스타벅스
# 128237  부산광역시 강서구 명지국제7로  128.905512  35.097565       스타벅스
# 128880      부산광역시 남구 못골로  129.091920  35.136133       스타벅스
# 128883   부산광역시 해운대구 해운대로  129.177094  35.170597       스타벅스
# 129268     부산광역시 금정구 금강로  129.088734  35.246960       스타벅스
#
# [119 rows x 12 columns]

# %%
df_cafe = df[df["상호명_소문자"].str.contains("이디야|이디아|ediya|스타벅스|starbucks")].copy()

# %%
df_cafe.loc[df_cafe["상호명_소문자"].str.contains("이디야|이디아|ediya"), "브랜드명"] = "이디야"
df_cafe.loc[~df_cafe["상호명_소문자"].str.contains("이디야|이디아|ediya"), "브랜드명"] = "스타벅스"

# %%
df_cafe
# Out:
#               상호명 상권업종대분류명 상권업종중분류명     상권업종소분류명    시도명  시군구명  행정동명 법정동명  \
# 294         이디야커피       음식   커피점/카페  커피전문점/카페/다방  부산광역시  해운대구  반송1동  반송동
# 787         이디야커피       음식   커피점/카페  커피전문점/카페/다방  부산광역시   사하구  다대1동  다대동
# 2080        이디아커피       음식   커피점/카페  커피전문점/카페/다방  부산광역시    동구  초량3동  초량동
# 2765         스타벅스       음식   커피점/카페  커피전문점/카페/다방  부산광역시    동구  초량3동  초량동
# 5505         스타벅스       음식   커피점/카페  커피전문점/카페/다방  부산광역시   연제구  연산4동  연산동
# ...           ...      ...      ...          ...    ...   ...   ...  ...
# 129201      이디야커피       음식   커피점/카페  커피전문점/카페/다방  부산광역시   동래구   수민동  수안동
# 129268       스타벅스       음식   커피점/카페  커피전문점/카페/다방  부산광역시   금정구  구서1동  구서동
# 131192  에이디아트트립커피       음식   커피점/카페  커피전문점/카페/다방  부산광역시    동구  수정2동  수정동
# 135049        이디아       음식   커피점/카페  커피전문점/카페/다방  부산광역시   수영구   민락동  민락동
# 139265   제이디아이스포츠      스포츠   실내운동시설        스포츠센터  부산광역시    동구  범일2동  범일동
#
#                        도로명          경도         위도    상호명_소문자  브랜드명
# 294       부산광역시 해운대구 아랫반송로  129.148858  35.225032      이디야커피   이디야
# 787          부산광역시 사하구 다대로  128.966690  35.048200      이디야커피   이디야
# 2080    부산광역시 동구 중앙대로332번길  129.046114  35.125441      이디아커피   이디야
# 2765         부산광역시 동구 중앙대로  129.040831  35.116346       스타벅스  스타벅스
# 5505         부산광역시 연제구 반송로  129.083344  35.186967       스타벅스  스타벅스
# ...                    ...         ...        ...        ...   ...
# 129201  부산광역시 동래구 명륜로112번길  129.084789  35.203152      이디야커피   이디야
# 129268       부산광역시 금정구 금강로  129.088734  35.246960       스타벅스  스타벅스
# 131192        부산광역시 동구 수정로  129.045899  35.127489  에이디아트트립커피   이디야
# 135049     부산광역시 수영구 광안해변로  129.129792  35.161088        이디아   이디야
# 139265        부산광역시 동구 범일로  129.058597  35.141323   제이디아이스포츠   이디야
#
# [238 rows x 13 columns]

# %% [markdown]
# ## 업종 분류를 활용하여 불필요한 데이터 삭제

# %%
df_cafe = df_cafe[df_cafe["상권업종중분류명"] == "커피점/카페"].copy()

# %%
df_cafe["상권업종중분류명"].value_counts()
# Out:
# 커피점/카페    229
# Name: 상권업종중분류명, dtype: int64

# %% [markdown]
# ## 시각화를 사용한 확인

# %%
sns.countplot(data=df_cafe, x="시군구명", hue="브랜드명")
# Out:
# <AxesSubplot:xlabel='시군구명', ylabel='count'>

# %%
df_cafe[["위도", "경도"]].plot.scatter(x="경도", y="위도")
# Out:
# <AxesSubplot:xlabel='경도', ylabel='위도'>

# %%
sns.scatterplot(data=df_cafe, x="경도", y="위도", hue="브랜드명")
# Out:
# <AxesSubplot:xlabel='경도', ylabel='위도'>

# %%
sns.jointplot(data=df_cafe, x="경도", y="위도", hue="브랜드명")

# %% [markdown]
# ## 지도 시각화

# %%
import folium

# %%
lat = df_cafe["위도"].mean()
long = df_cafe["경도"].mean()

# %%
m = folium.Map([lat, long], zoom_start=12, tiles="Stamen Toner")

# %%
for i in df_cafe.index:
    sub_lat = df_cafe.loc[i, "위도"]
    sub_long = df_cafe.loc[i, "경도"]
    title = f"{df_cafe.loc[i, '상호명']}-{df_cafe.loc[i, '도로명']}"
    color = "green"
    if df_cafe.loc[i, "브랜드명"] == "이디야":
        color = "blue"
    folium.CircleMarker([sub_lat, sub_long], radius=3, color=color, tooltip=title).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_068baa559c123598ab10a36c71f6b3e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_068baa559c123598ab10a36c71f6b3e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_068baa559c123598ab10a36c71f6b3e8 = L.map(
#                 &quot;map_068baa559c123598ab10a36c71f6b3e8&quot;,
#                 {
#                     center: [35.16434226810546, 129.07248047484046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cedf52b880ca30f1f1f56e8c03538754 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_068baa559c123598ab10a36c71f6b3e8);
#
#
#             var circle_marker_9b89488b765fdcf4c29a9efa9d2ece43 = L.circleMarker(
#                 [35.2250323189732, 129.148857710525],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_068baa559c123598ab10a36c71f6b3e8);
#
#
#             circle_marker_9b89488b765fdcf4c29a9efa9d2ece43.bindTooltip(
#                 `&lt;div&gt;
#                      이디야커피-부산광역시 해운대구 아랫반송로
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_fbe961d75803fdca730f15d689803f0e = L.circleMarker(
#                 [35.0482002400717, 128.966690081527],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_068baa559c123598ab10a36c71f6b3e8);
#
#
#             circle_marker_fbe961d75803fdca730f15d689803f0e.bindTooltip(
#                 `&lt;div&gt;
#                      이디야커피-부산광역시 사하구 다대로
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_233282cbff81d8b776fb51d6e3ff34e3 = L.circleMarker(
#                 [35.1254407067016, 129.046114238087],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_068baa559c123598ab10a36c71f6b3e8);
#
#
#             circle_marker_233282cbff81d8b776fb51d6e3ff34e3.bindTooltip(
#                 `&lt;div&gt;
#                      이디아커피-부산광역시 동구 중앙대로332번길
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_c63f06dcc97463b4a56ac110b1000877 = L.circleMarker(
#                 [35.1163460024434, 129.040830967932],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_068baa559c123598ab10a36c71f6b3e8);
#
#
#             circle_marker_c63f06dcc97463b4a56ac110b1000877.bindTooltip(
#                 `&lt;div&gt;
#                      스타벅스-부산광역시 동구 중앙대로
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_b08f54c2ff42fb4a1e139447b1385faa = L.circleMarker(
#                 [35.1869670403599, 129.083343934019],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &

# %% [markdown]
# ## 카토그램을 활용한 시각화

# %%
import json

# %%
m = folium.Map([lat, long])

# %%
geo_json = json.load(open("../dataset/preprocessing/Busan_GeoJSON.json", encoding="utf-8"))

# %%
df_cafe_vs = df_cafe.groupby(["시군구명", "브랜드명"])["상호명"].count()
df_cafe_vs = df_cafe_vs.reset_index()
df_cafe_vs.head()
# Out:
#   시군구명  브랜드명  상호명
# 0  강서구  스타벅스    3
# 1  강서구   이디야    8
# 2  금정구  스타벅스    8
# 3  금정구   이디야    8
# 4  기장군  스타벅스    4

# %%
df_star = df_cafe_vs[df_cafe_vs["브랜드명"]=="스타벅스"].copy()

# %%
folium.Choropleth(geo_data=geo_json, 
                  name="choropleth", 
                  data=df_star, 
                  columns=["시군구명", "상호명"],
                  key_on="feature.properties.name",
                  fill_color="YlGn",
                  fill_opacity=0.7,
                  line_opacity=0.2,
                  legend_name="스타벅스 매장수"
                 ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1df5aec29c08cab92ac9f170a745041 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1df5aec29c08cab92ac9f170a745041&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d1df5aec29c08cab92ac9f170a745041 = L.map(
#                 &quot;map_d1df5aec29c08cab92ac9f170a745041&quot;,
#                 {
#                     center: [35.16434226810546, 129.07248047484046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d49ce3ee491a36a170d660cca64c282a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d1df5aec29c08cab92ac9f170a745041);
#
#
#             var choropleth_ae3459273a9418c41d91c622d25e849b = L.featureGroup(
#                 {}
#             ).addTo(map_d1df5aec29c08cab92ac9f170a745041);
#
#
#         function geo_json_99d53bfa6051e40aec747564611ea245_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uc911\uad6c&quot;: case &quot;\uc0ac\ud558\uad6c&quot;: case &quot;\uae08\uc815\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\ubd80\uc0b0\uc9c4\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\ud574\uc6b4\ub300\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_99d53bfa6051e40aec747564611ea245_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_99d53bfa6051e40aec747564611ea245 = L.geoJson(null, {
#                 onEachFeature: geo_json_99d53bfa6051e40aec747564611ea245_onEachFeature,
#
#                 style: geo_json_99d53bfa6051e40aec747564611ea245_styler,
#         });
#
#         function geo_json_99d53bfa6051e40aec747564611ea245_add (data) {
#             geo_json_99d53bfa6051e40aec747564611ea245
#                 .addData(data)
#                 .addTo(choropleth_ae3459273a9418c41d91c622d25e849b);
#         }
#             geo_json_99d53bfa6051e40aec747564611ea245_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.032, 35.116], [129.038, 35.112], [129.042, 35.111], [129.041, 35.108], [129.038, 35.104], [129.038, 35.098], [129.037, 35.097], [129.029, 35.096], [129.026, 35.096], [129.024, 35.1], [129.022, 35.102], [129.021, 35.106], [129.023, 35.109], [129.024, 35.109], [129.026, 35.111], [129.028, 35.11], [129.028, 35.115], [129.032, 35.116]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uc911\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;21010&quot;, &quot;name&quot;: &quot;\uc911\uad6c&quot;, &quot;name_eng&quot;: &quot;Jung-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.023, 35.076], [129.021, 35.078], [129.018, 35.077], [129.017, 35.074], [129.019, 35.07], [129.021, 35.07], [129.021, 35.066], [129.02, 35.065], [129.022, 35.062], [129.019, 35.059], [129.018, 35.058], [129.016, 35.057], [129.015, 35.053], [129.012, 35.052], [129.008, 35.063], [129.011, 35.063], [129.012, 35.065], [129.009, 35.066], [129.006, 35.071], [129.004, 35.078], [129.008, 35.079], [129.011, 35.077], [129.012, 35.08], [129.011, 35.083], [129.012, 35.084], [129.014, 35.091], [129.014, 35.094], [129.01, 35.099], [129.007, 35.1], [129.007, 35.101], [129.01, 35.106], [129.006, 35.109], [129.004, 35.111], [129.004, 35.113], [129.002, 35.114], [129.003, 35.117], [128.999, 35.119], [129, 35.124], [129.003, 35.125], [129.003, 35.131], [129.003, 35.134], [129.004, 35.136], [128.996, 35.14], [128.998, 35.141], [129.002, 35.141], [129.004, 35.139], [129.008, 35.14], [129.011, 35.139], [129.013, 35.137], [129.016, 35.136], [129.022, 35.137], [129.026, 35.136], [129.026, 35.133], [129.026, 35.126], [129.026, 35.125], [129.025, 35.122], [129.025, 35.118], [129.027, 35.116], [129.028, 35.112], [129.024, 35.109], [129.023, 35.109], [129.021, 35.106], [129.022, 35.102], [129.024, 35.1], [129.026, 35.096], [129.025, 35.094], [129.027, 35.085], [129.024, 35.076], [129.023, 35.

# %%
m = folium.Map([lat, long], tiles='stamen toner')

folium.Choropleth(
    geo_data=geo_json,
    name='choropleth',
    data=df_star,
    columns=["시군구명", "상호명"],
    key_on='feature.properties.name',
    fill_color='Blues',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="스타벅스 매장수"
).add_to(m)

for i in df_cafe.index:
    sub_lat = df_cafe.loc[i, "위도"]
    sub_long = df_cafe.loc[i, "경도"]
    title = f"{df_cafe.loc[i, '상호명']} - {df_cafe.loc[i, '도로명']}"
    color = "green"
    if df_cafe.loc[i, "브랜드명"] == "스타벅스":
        color = "blue"
    
    folium.CircleMarker([sub_lat, sub_long],
                        radius=3,
                        color=color,
                        tooltip=title).add_to(m)
